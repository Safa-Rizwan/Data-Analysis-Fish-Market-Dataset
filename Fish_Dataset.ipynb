# %% [markdown]
# # Importing Python Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# # Reading Dataset

# %%
data = pd.read_csv('Fish_dataset.csv')
data
# Out:
#       ID Species  Weight  Length1  Length2  Length3   Height   Width
# 0      1   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1      2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2      3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3      4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4      5   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..   ...     ...     ...      ...      ...      ...      ...     ...
# 154  155   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155  156   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156  157   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157  158   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158  159   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 8 columns]

# %% [markdown]
# # Exploring Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       159 non-null    int64
#  1   Species  159 non-null    object
#  2   Weight   159 non-null    float64
#  3   Length1  159 non-null    float64
#  4   Length2  159 non-null    float64
#  5   Length3  159 non-null    float64
#  6   Height   159 non-null    float64
#  7   Width    159 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 10.1+ KB

# %%
data.describe()
# Out:
#                ID       Weight     Length1     Length2     Length3  \
# count  159.000000   159.000000  159.000000  159.000000  159.000000
# mean    80.000000   398.326415   26.247170   28.415723   31.227044
# std     46.043458   357.978317    9.996441   10.716328   11.610246
# min      1.000000     0.000000    7.500000    8.400000    8.800000
# 25%     40.500000   120.000000   19.050000   21.000000   23.150000
# 50%     80.000000   273.000000   25.200000   27.300000   29.400000
# 75%    119.500000   650.000000   32.700000   35.500000   39.650000
# max    159.000000  1650.000000   59.000000   63.400000   68.000000
#
#            Height       Width
# count  159.000000  159.000000
# mean     8.970994    4.417486
# std      4.286208    1.685804
# min      1.728400    1.047600
# 25%      5.944800    3.385650
# 50%      7.786000    4.248500
# 75%     12.365900    5.584500
# max     18.957000    8.142000

# %% [markdown]
# # Checking Null Values

# %%
data.isnull().value_counts()
# Out:
# ID     Species  Weight  Length1  Length2  Length3  Height  Width
# False  False    False   False    False    False    False   False    159
# dtype: int64

# %%
data.isna().value_counts()
# Out:
# ID     Species  Weight  Length1  Length2  Length3  Height  Width
# False  False    False   False    False    False    False   False    159
# dtype: int64

# %% [markdown]
# # Checking Duplicates

# %%
data.duplicated().value_counts()
# Out:
# False    159
# dtype: int64

# %% [markdown]
# # Conversion of Categorical Feature into Numeric"

# %%
data['Species'].value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %% [markdown]
# * Perch        0
# * Bream        1
# * Roach        2
# * Pike         3
# * Smelt        4
# * Parkki       5
# * Whitefish    6

# %%
data['Species']= data['Species'].replace('Perch',0)
data['Species']= data['Species'].replace('Bream',1)
data['Species']= data['Species'].replace('Roach',2)
data['Species']= data['Species'].replace('Pike',3)
data['Species']= data['Species'].replace('Smelt',4)
data['Species']= data['Species'].replace('Parkki',5)
data['Species']= data['Species'].replace('Whitefish',6)

# %%
data
# Out:
#       ID  Species  Weight  Length1  Length2  Length3   Height   Width
# 0      1        1   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1      2        1   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2      3        1   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3      4        1   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4      5        1   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..   ...      ...     ...      ...      ...      ...      ...     ...
# 154  155        4    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155  156        4    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156  157        4    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157  158        4    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158  159        4    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 8 columns]

# %% [markdown]
# # Feature Scaling - Standardization

# %%
column_headers = [ "ID",  "Species", "Weight", "Length1", "Length2", "Length3", "Height", "Width"]
std_scaler = StandardScaler()
data = pd.DataFrame(std_scaler.fit_transform(data), columns=column_headers)

# %%
data
# Out:
#            ID   Species    Weight   Length1   Length2   Length3    Height  \
# 0   -1.721191 -0.398670 -0.438072 -0.305789 -0.282303 -0.106020  0.596579
# 1   -1.699404 -0.398670 -0.303562 -0.225507 -0.198054 -0.002337  0.821261
# 2   -1.677617 -0.398670 -0.163448 -0.235542 -0.179332 -0.010977  0.797341
# 3   -1.655830 -0.398670 -0.098995  0.005302  0.054694  0.196390  0.879771
# 4   -1.634043 -0.398670  0.088759  0.025372  0.054694  0.239592  0.812835
# ..        ...       ...       ...       ...       ...       ...       ...
# 154  1.634043  1.269448 -1.082039 -1.479903 -1.517960 -1.540309 -1.610359
# 155  1.655830  1.269448 -1.078676 -1.459833 -1.499238 -1.531669 -1.530878
# 156  1.677617  1.269448 -1.082039 -1.419692 -1.443072 -1.505748 -1.566687
# 157  1.699404  1.269448 -1.061022 -1.309305 -1.321378 -1.384784 -1.427243
# 158  1.721191  1.269448 -1.060461 -1.249094 -1.255851 -1.298381 -1.413341
#
#         Width
# 0   -0.236529
# 1   -0.066579
# 2    0.165793
# 3    0.022621
# 4    0.426371
# ..        ...
# 154 -1.799403
# 155 -1.873547
# 156 -1.881402
# 157 -1.398568
# 158 -1.510440
#
# [159 rows x 8 columns]
